# %%
import pandas as pd
import os
import zipfile
import torch
import torchvision.transforms as transforms
from torchvision import models
from PIL import Image
from tqdm import tqdm
import numpy as np

# %%
# !wget https://www.dropbox.com/s/57tel5zqopkssrh/books.csv?dl=0 -O books.csv
# !wget https://www.dropbox.com/s/zpnnoy1i8ljf9fg/goodreads_bert_embeddings.npy?dl=0 -O goodreads_bert_embeddings.npy
# !wget https://www.dropbox.com/s/a8hcc9w30y7r3jl/goodreads_bert_large_embeddings.npy?dl=0 -O goodreads_bert_large_embeddings.npy
# !wget https://www.dropbox.com/s/dqeqpsr0vdvmcy0/goodreads_past_interactions.json?dl=0 -O goodreads_past_interactions.json
# !wget https://www.dropbox.com/s/rjtzhmb2zbpp30q/goodreads_test_interactions.json?dl=0 -O goodreads_test_interactions.json
# Out:
# --2025-06-06 23:23:55--  https://www.dropbox.com/s/57tel5zqopkssrh/books.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/5s6xrfnu17yi34sfhmskb/books.csv?rlkey=ymzokbyqw3qq2bq5okfao9w1z&dl=0 [following]
# --2025-06-06 23:23:55--  https://www.dropbox.com/scl/fi/5s6xrfnu17yi34sfhmskb/books.csv?rlkey=ymzokbyqw3qq2bq5okfao9w1z&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucdd0eb389c7c5e670a2d163d3c6.dl.dropboxusercontent.com/cd/0/inline/CrIgHvJHDbFF2zs6bJS7C9Ec-cRKpN4b37jCS9bBoTsr0JTVSo8CYf1sjwqpHsgJcI4UuRNaIAgfHHr8JKR7VFQOf8xZmi0bsqxTnU63FHrBl2RdS-tkrgPOHETuX_ufdhVwryhbbNGKvunnMkGi08aP/file# [following]
# --2025-06-06 23:23:55--  https://ucdd0eb389c7c5e670a2d163d3c6.dl.dropboxusercontent.com/cd/0/inline/CrIgHvJHDbFF2zs6bJS7C9Ec-cRKpN4b37jCS9bBoTsr0JTVSo8CYf1sjwqpHsgJcI4UuRNaIAgfHHr8JKR7VFQOf8xZmi0bsqxTnU63FHrBl2RdS-tkrgPOHETuX_ufdhVwryhbbNGKvunnMkGi08aP/file
# Resolving ucdd0eb389c7c5e670a2d163d3c6.dl.dropboxusercontent.com (ucdd0eb389c7c5e670a2d163d3c6.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:601c:15::a27d:60f
# Connecting to ucdd0eb389c7c5e670a2d163d3c6.dl.dropboxusercontent.com (ucdd0eb389c7c5e670a2d163d3c6.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5156485 (4.9M) [text/plain]
# Saving to: ‘books.csv’
#
# books.csv           100%[===================>]   4.92M  --.-KB/s    in 0.09s
#
# 2025-06-06 23:23:56 (54.3 MB/s) - ‘books.csv’ saved [5156485/5156485]
#
# --2025-06-06 23:23:56--  https://www.dropbox.com/s/zpnnoy1i8ljf9fg/goodreads_bert_embeddings.npy?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/9t24trwzk8smammwnvvxw/goodreads_bert_embeddings.npy?rlkey=cj0axwkdtbcc94vb4lpj1cdj7&dl=0 [following]
# --2025-06-06 23:23:56--  https://www.dropbox.com/scl/fi/9t24trwzk8smammwnvvxw/goodreads_bert_embeddings.npy?rlkey=cj0axwkdtbcc94vb4lpj1cdj7&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc0f850b3da2e9067cb6b0e62e93.dl.dropboxusercontent.com/cd/0/inline/CrLOuh7nGB6S3nxwtTUaxl6O7pKD2ExaYsOz1EWgBJ5IIamw9kXlpn16lDxIxvqpoqHx0ySWwJAW4Ygecx8vzV5kG-iKGmI9wMOT5xBukbf8-r8SgUW9ez4ld2n0iRGFiZNPfUlnLzblTB19K8yXy6De/file# [following]
# --2025-06-06 23:23:57--  https://uc0f850b3da2e9067cb6b0e62e93.dl.dropboxusercontent.com/cd/0/inline/CrLOuh7nGB6S3nxwtTUaxl6O7pKD2ExaYsOz1EWgBJ5IIamw9kXlpn16lDxIxvqpoqHx0ySWwJAW4Ygecx8vzV5kG-iKGmI9wMOT5xBukbf8-r8SgUW9ez4ld2n0iRGFiZNPfUlnLzblTB19K8yXy6De/file
# Resolving uc0f850b3da2e9067cb6b0e62e93.dl.dropboxusercontent.com (uc0f850b3da2e9067cb6b0e62e93.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:601c:15::a27d:60f
# Connecting to uc0f850b3da2e9067cb6b0e62e93.dl.dropboxusercontent.com (uc0f850b3da2e9067cb6b0e62e93.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CrKHW64AEYJT1r1pLliCQ6kVk5gz-dWx1hajPDCKMpdpOTtmHz_66vlaCCXZ7J92YWPW_SbgZATu85dIT1hLr-UafGVhB7LxhF4nKS65fDF2V9Rq4LoOfhex5GkZ4BeWDz5dpNistLoRzljYpinDnck0_8qD-nmp4o52i6RfeS91iCHDE8u6-PxXzh3LjltPddbV3kKRIKKBGvxuqHkAXx9DNTC05rFvNvQtaV5846ofgNdazTbWSxKT4lKoUdQIhaAfl0Nf5zgQ8Yu5QUvGBnJr4DwCwmQBomZKnEYhyVM9iOM75fn8SsQY0QSbCoUcYMNyjoDG7RGrPcmjIuQnpgQ0pDXCO-X8ENz2SoNUd74RMoPUfhy2x_c2cWjH86Lfdtg/file [following]
# --2025-06-06 23:23:57--  https://uc0f850b3da2e9067cb6b0e62e93.dl.dropboxusercontent.com/cd/0/inline2/CrKHW64AEYJT1r1pLliCQ6kVk5gz-dWx1hajPDCKMpdpOTtmHz_66vlaCCXZ7J92YWPW_SbgZATu85dIT1hLr-UafGVhB7LxhF4nKS65fDF2V9Rq4LoOfhex5GkZ4BeWDz5dpNistLoRzljYpinDnck0_8qD-nmp4o52i6RfeS91iCHDE8u6-PxXzh3LjltPddbV3kKRIKKBGvxuqHkAXx9DNTC05rFvNvQtaV5846ofgNdazTbWSxKT4lKoUdQIhaAfl0Nf5zgQ8Yu5QUvGBnJr4DwCwmQBomZKnEYhyVM9iOM75fn8SsQY0QSbCoUcYMNyjoDG7RGrPcmjIuQnpgQ0pDXCO-X8ENz2SoNUd74RMoPUfhy2x_c2cWjH86Lfdtg/file
# Reusing existing connection to uc0f850b3da2e9067cb6b0e62e93.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 26339456 (25M) [application/octet-stream]
# Saving to: ‘goodreads_bert_embeddings.npy’
#
# goodreads_bert_embe 100%[===================>]  25.12M   134MB/s    in 0.2s
#
# 2025-06-06 23:23:58 (134 MB/s) - ‘goodreads_bert_embeddings.npy’ saved [26339456/26339456]
#
# --2025-06-06 23:23:58--  https://www.dropbox.com/s/a8hcc9w30y7r3jl/goodreads_bert_large_embeddings.npy?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/9758hmxzeyylo0n4m3m3u/goodreads_bert_large_embeddings.npy?rlkey=xajdff8iigyfc7fin0i9rbgkb&dl=0 [following]
# --2025-06-06 23:23:58--  https://www.dropbox.com/scl/fi/9758hmxzeyylo0n4m3m3u/goodreads_bert_large_embeddings.npy?rlkey=xajdff8iigyfc7fin0i9rbgkb&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc60140a96a8a41d5653d54c34d1.dl.dropboxusercontent.com/cd/0/inline/CrLHUIjNtMAlRIiqfmKvtShdJ33AWibuHO0hXhuQlicC_BhzoQJ0H0vclOvmmi9aeT-1xhxlHS88CXycp6nLAYG6uPQ5E3hhhnzhi-UpHFulYO9HmpVMR5budnvVjMxcc5idTp7AA-eihVw9dn0VQP_6/file# [following]
# --2025-06-06 23:23:58--  https://uc60140a96a8a41d5653d54c34d1.dl.dropboxusercontent.com/cd/0/inline/CrLHUIjNtMAlRIiqfmKvtShdJ33AWibuHO0hXhuQlicC_BhzoQJ0H0vclOvmmi9aeT-1xhxlHS88CXycp6nLAYG6uPQ5E3hhhnzhi-UpHFulYO9HmpVMR5budnvVjMxcc5idTp7AA-eihVw9dn0VQP_6/file
# Resolving uc60140a96a8a41d5653d54c34d1.dl.dropboxusercontent.com (uc60140a96a8a41d5653d54c34d1.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:601c:15::a27d:60f
# Connecting to uc60140a96a8a41d5653d54c34d1.dl.dropboxusercontent.com (uc60140a96a8a41d5653d54c34d1.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CrKn05heUvVMZ6R_9gaZHbZ37dZcz3O9pV7kHi4N15L6s57m5rwuqCvGMtTF2QpeacXGlUQGHNbNjD2P2Rhvt2bV-M8fH7Ev7ce08znmzxhbzNBIv3FpLYJmP2jZvcXW1jqifMsR9KXlVbjN8WmbeZVRvi-pJ6q9BFITCwEP3QbtMYeFAQJ-MI2Ih7jnTwRCVp7Q9yV5LeSDWB3G8lmhNAhY6P6iwn1WJPd-Lo1h6JHdQFccMQGiZTc2rt0RY55_jZ5-ItJc0NmKYXz230Sbn_NGwoIervI17MaQwxixojaXdxLFsgszT4jnKR3SFDDXvnEmIbKVfxakZ10OppHaZd8yZFz70GdAVJadzNGje26dAx7qGF7E0AFe3G7cvaY-gs8/file [following]
# --2025-06-06 23:23:59--  https://uc60140a96a8a41d5653d54c34d1.dl.dropboxusercontent.com/cd/0/inline2/CrKn05heUvVMZ6R_9gaZHbZ37dZcz3O9pV7kHi4N15L6s57m5rwuqCvGMtTF2QpeacXGlUQGHNbNjD2P2Rhvt2bV-M8fH7Ev7ce08znmzxhbzNBIv3FpLYJmP2jZvcXW1jqifMsR9KXlVbjN8WmbeZVRvi-pJ6q9BFITCwEP3QbtMYeFAQJ-MI2Ih7jnTwRCVp7Q9yV5LeSDWB3G8lmhNAhY6P6iwn1WJPd-Lo1h6JHdQFccMQGiZTc2rt0RY55_jZ5-ItJc0NmKYXz230Sbn_NGwoIervI17MaQwxixojaXdxLFsgszT4jnKR3SFDDXvnEmIbKVfxakZ10OppHaZd8yZFz70GdAVJadzNGje26dAx7qGF7E0AFe3G7cvaY-gs8/file
# Reusing existing connection to uc60140a96a8a41d5653d54c34d1.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 35119232 (33M) [application/octet-stream]
# Saving to: ‘goodreads_bert_large_embeddings.npy’
#
# goodreads_bert_larg 100%[===================>]  33.49M  66.7MB/s    in 0.5s
#
# 2025-06-06 23:24:00 (66.7 MB/s) - ‘goodreads_bert_large_embeddings.npy’ saved [35119232/35119232]
#
# --2025-06-06 23:24:00--  https://www.dropbox.com/s/dqeqpsr0vdvmcy0/goodreads_past_interactions.json?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/4crrafugs93pzf3xshahz/goodreads_past_interactions.json?rlkey=w58hjav618jk0iyti1c4f85ad&dl=0 [following]
# --2025-06-06 23:24:00--  https://www.dropbox.com/scl/fi/4crrafugs93pzf3xshahz/goodreads_past_interactions.json?rlkey=w58hjav618jk0iyti1c4f85ad&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce5bfd9b5e2277d9a26f9367859.dl.dropboxusercontent.com/cd/0/inline/CrJtZYey_QjXL8Jxb51C5eMtidnAyYXSRu05m8ToVjltBen8xOeYHp4ZN_gTcX5pWWnhNktGQopAacSecE34Thv-t7Ov4shbk9kiwHb9u7fouZWYdLessCroWBfDE7FfCzBjle56wHC0U31NoDhk3_3-/file# [following]
# --2025-06-06 23:24:00--  https://uce5bfd9b5e2277d9a26f9367859.dl.dropboxusercontent.com/cd/0/inline/CrJtZYey_QjXL8Jxb51C5eMtidnAyYXSRu05m8ToVjltBen8xOeYHp4ZN_gTcX5pWWnhNktGQopAacSecE34Thv-t7Ov4shbk9kiwHb9u7fouZWYdLessCroWBfDE7FfCzBjle56wHC0U31NoDhk3_3-/file
# Resolving uce5bfd9b5e2277d9a26f9367859.dl.dropboxusercontent.com (uce5bfd9b5e2277d9a26f9367859.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:601c:15::a27d:60f
# Connecting to uce5bfd9b5e2277d9a26f9367859.dl.dropboxusercontent.com (uce5bfd9b5e2277d9a26f9367859.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17685887 (17M) [text/plain]
# Saving to: ‘goodreads_past_interactions.json’
#
# goodreads_past_inte 100%[===================>]  16.87M  69.4MB/s    in 0.2s
#
# 2025-06-06 23:24:01 (69.4 MB/s) - ‘goodreads_past_interactions.json’ saved [17685887/17685887]
#
# --2025-06-06 23:24:01--  https://www.dropbox.com/s/rjtzhmb2zbpp30q/goodreads_test_interactions.json?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/slomhi7icrvh57rbo8e92/goodreads_test_interactions.json?rlkey=9xe06jxsx4hncbg9w9wekj93l&dl=0 [following]
# --2025-06-06 23:24:01--  https://www.dropbox.com/scl/fi/slomhi7icrvh57rbo8e92/goodreads_test_interactions.json?rlkey=9xe06jxsx4hncbg9w9wekj93l&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce6f0b4fad50aadfcf8c620e93d.dl.dropboxusercontent.com/cd/0/inline/CrJJ5Z9xuE2YdKLOQsLeN1j9bJPT1f-RADEavMDDErYcdympIZcztp2DrtSzB5qeKhSu6ZnfJ5Np-R1btf3mWupCRiNmGEJwPQxLoEGaRszTYLd2w23rycpHTu7mEUZJFJPPQXic2hs1kcXYz752L6qj/file# [following]
# --2025-06-06 23:24:02--  https://uce6f0b4fad50aadfcf8c620e93d.dl.dropboxusercontent.com/cd/0/inline/CrJJ5Z9xuE2YdKLOQsLeN1j9bJPT1f-RADEavMDDErYcdympIZcztp2DrtSzB5qeKhSu6ZnfJ5Np-R1btf3mWupCRiNmGEJwPQxLoEGaRszTYLd2w23rycpHTu7mEUZJFJPPQXic2hs1kcXYz752L6qj/file
# Resolving uce6f0b4fad50aadfcf8c620e93d.dl.dropboxusercontent.com (uce6f0b4fad50aadfcf8c620e93d.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:601c:15::a27d:60f
# Connecting to uce6f0b4fad50aadfcf8c620e93d.dl.dropboxusercontent.com (uce6f0b4fad50aadfcf8c620e93d.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6111 (6.0K) [text/plain]
# Saving to: ‘goodreads_test_interactions.json’
#
# goodreads_test_inte 100%[===================>]   5.97K  --.-KB/s    in 0s
#
# 2025-06-06 23:24:02 (1.75 GB/s) - ‘goodreads_test_interactions.json’ saved [6111/6111]

# %%
# Unzip the covers
with zipfile.ZipFile("book_covers.zip", 'r') as zip_ref:
    zip_ref.extractall("book_covers")

# %%
books_df = pd.read_csv("books.csv")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Cargar ResNet50 y eliminar capa de clasificación
resnet = models.resnet50(pretrained=True)
resnet.fc = torch.nn.Identity()  # eliminar capa de clasificación
resnet = resnet.to(device)
resnet.eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Identity()
# )

# %%
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
image_folder = "book_covers/book_covers"
embeddings = []

for idx in tqdm(range(len(books_df))):
    image_path = os.path.join(image_folder, f"book_{idx}.jpg")

    try:
        image = Image.open(image_path).convert("RGB")
        image_tensor = transform(image).unsqueeze(0).to(device)
        with torch.no_grad():
            embedding = resnet(image_tensor)
        embeddings.append(embedding.cpu().numpy().squeeze())
    except Exception as e:
        print(f"Error with image {idx}: {e}")
        embeddings.append(np.zeros(2048))  # fallback

# Convert to numpy array and save for future use
image_embeddings = np.array(embeddings)
np.save("resnet_book_embeddings.npy", image_embeddings)
# Out:
# 100%|██████████| 4287/4287 [02:35<00:00, 27.53it/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(image_embeddings)

# Crear función para recomendar libros similares en base a similitud de coseno
def recommend_books(book_index, top_k=10):
  sim_scores = similarity_matrix[book_index]

  # Excluir propio libro
  sim_scores[book_index] = -1

  # Obtener top k índices
  top_indices = sim_scores.argsort()[::-1][:top_k]

  return books_df.iloc[top_indices][["title", "authors", "average_rating"]]

# %%
book_id = 10
print("Libro seleccionado:")
print(books_df.iloc[book_id][["title", "authors", "average_rating"]])

print("\Libros recomendados:")
recommend_books(book_id, 10)
# Out:
# Libro seleccionado:
# title             Divergent (Divergent, #1)
# authors                       Veronica Roth
# average_rating                         4.24
# Name: 10, dtype: object
# \Libros recomendados:
#                                                   title  \
# 1539                Monsters of Men (Chaos Walking, #3)
# 730   Four: A Divergent Story Collection (Divergent,...
# 1248            The Young Elites (The Young Elites, #1)
# 2025   The Thousand-Dollar Tan Line (Veronica Mars, #1)
# 153             Dead Until Dark (Sookie Stackhouse, #1)
# 781                               The Amityville Horror
# 976                                     Flight Behavior
# 3074                            His Last Bow: 8 Stories
# 305                              Breakfast of Champions
# 438     The Absolutely True Diary of a Part-Time Indian
#
#                            authors  average_rating
# 1539                  Patrick Ness            4.25
# 730                  Veronica Roth            4.10
# 1248                      Marie Lu            3.93
# 2025   Rob Thomas, Jennifer Graham            3.99
# 153               Charlaine Harris            3.96
# 781                      Jay Anson            3.82
# 976             Barbara Kingsolver            3.75
# 3074            Arthur Conan Doyle            4.27
# 305              Kurt Vonnegut Jr.            4.08
# 438   Sherman Alexie, Ellen Forney            4.11

# %%
# Analyze embeddings format
print(image_embeddings.shape)
print(image_embeddings[0])
# Out:
# (4287, 2048)
# [0.00362244 0.         0.82107866 ... 0.         0.1243109  0.26179948]

# %%
import json

with open("goodreads_past_interactions.json") as f:
    train_interactions = json.load(f)

with open("goodreads_test_interactions.json") as f:
    test_interactions = json.load(f)

# %%
bookid2idx = {id_: i for i, id_ in enumerate(books_df.book_id)}
idx2bookid = {i: id_ for i, id_ in enumerate(books_df.book_id)}

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Función que calcula la media de los embeddings de interacciones del usuario y genera recomendaciones en base a eso
def recommend_for_user(user_books, top_k=10):
    vectors = []

    for book_id in user_books:
        if book_id in bookid2idx:
            vectors.append(image_embeddings[bookid2idx[book_id]])

    if not vectors:
        return []

    user_profile = np.mean(vectors, axis=0).reshape(1, -1)
    similarities = cosine_similarity(user_profile, image_embeddings).flatten()

    # Eliminar libros con los cuales el usuario ya interactuo
    for book_id in user_books:
        if book_id in bookid2idx:
            similarities[bookid2idx[book_id]] = -1

    top_indices = similarities.argsort()[::-1][:top_k]
    return [idx2bookid[i] for i in top_indices]

# %%
# Métricas de evaluación
def precision_at_k(preds, truth, k):
    return len(set(preds[:k]) & set(truth)) / k

def recall_at_k(preds, truth, k):
    return len(set(preds[:k]) & set(truth)) / len(truth) if truth else 0

def ndcg_at_k(preds, truth, k):
    dcg = 0.0
    for i, p in enumerate(preds[:k]):
        if p in truth:
            dcg += 1 / np.log2(i + 2)
    idcg = sum(1 / np.log2(i + 2) for i in range(min(len(truth), k)))
    return dcg / idcg if idcg > 0 else 0

def map_at_k(preds, truth, k):
    score = 0.0
    hits = 0
    for i, p in enumerate(preds[:k]):
        if p in truth:
            hits += 1
            score += hits / (i + 1)
    return score / min(len(truth), k) if truth else 0

# %%
K = 10
metrics = {
    "precision": [],
    "recall": [],
    "ndcg": [],
    "map": [],
}

users_evaluated = 0

for user, past_books in train_interactions.items():
    test_books = test_interactions.get(user, [])
    if not test_books:
        continue

    recommendations = recommend_for_user(past_books, top_k=K)

    metrics["precision"].append(precision_at_k(recommendations, test_books, K))
    metrics["recall"].append(recall_at_k(recommendations, test_books, K))
    metrics["ndcg"].append(ndcg_at_k(recommendations, test_books, K))
    metrics["map"].append(map_at_k(recommendations, test_books, K))

    users_evaluated += 1

# Imprimir promedio de métricas
print(f"Se evaluaron {users_evaluated} usuarios en total.\n")
for name, scores in metrics.items():
    print(f"{name.upper()}@{K}: {np.mean(scores):.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
#        0.3754183], dtype=float32), array([0.        , 0.4099214 , 0.50665355, ..., 0.24102816, 0.12368713,
#        0.55204254], dtype=float32), array([0.        , 0.12002135, 0.57231903, ..., 1.0070345 , 0.        ,
#        1.1893115 ], dtype=float32), array([0.        , 0.32854724, 0.2001894 , ..., 0.26274717, 0.        ,
#        0.08688491], dtype=float32), array([4.4973339e-03, 5.1574211e+00, 0.0000000e+00, ..., 0.0000000e+00,
#        0.0000000e+00, 5.7459455e+00], dtype=float32), array([0.        , 2.052932  , 0.00889368, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.3647148, 4.704932 ,
#        0.       ], dtype=float32), array([0.16899459, 0.8027674 , 0.5016459 , ..., 0.000845  , 0.        ,
#        0.19864911], dtype=float32), array([0.36229822, 2.7653048 , 0.        , ..., 0.        , 0.13091502,
#        0.19025283], dtype=float32), array([0.09263193, 0.70402014, 0.        , ..., 0.19787464, 0.        ,
#        0.03816366], dtype=float32), array([0.        , 0.        , 0.06466441, ..., 1.3687565 , 0.2578526 ,
#        0.30520442], dtype=float32), array([0.        , 1.169925  , 0.14430237, ..., 0.        , 0.        ,
#        0.69911397], dtype=float32), array([0.        , 1.0180924 , 0.13893896, ..., 0.06608152, 0.        ,
#        2.5403707 ], dtype=float32), array([0.2149861 , 2.9157844 , 0.9507679 , ..., 0.03083177, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.2150433 , ..., 0.        , 0.        ,
#        0.05349571], dtype=float32), array([0.        , 1.132587  , 0.2269721 , ..., 1.326092  , 0.07917526,
#        0.        ], dtype=float32), array([0.        , 0.70553297, 0.03506425, ..., 0.        , 0.3202642 ,
#        0.        ], dtype=float32), array([0.        , 2.5223398 , 0.07083167, ..., 0.01855993, 0.        ,
#        0.        ], dtype=float32), array([0.        , 1.9942929 , 0.16014352, ..., 0.04880018, 0.        ,
#        0.20353036], dtype=float32), array([0.        , 0.8573248 , 0.15160552, ..., 0.2926623 , 0.        ,
#        0.        ], dtype=float32), array([0.90556407, 0.33315587, 1.4998724 , ..., 0.44145292, 0.25627193,
#        0.        ], dtype=float32), array([0.        , 0.42708433, 0.4346453 , ..., 0.2051982 , 0.05703465,
#        0.07872121], dtype=float32), array([0.        , 4.5601006 , 0.17890953, ..., 0.        , 0.43218076,
#        0.        ], dtype=float32)]
# USER PROFILE:
# [[0.26581153 1.4839654  0.6031215  ... 0.2995256  0.3120582  0.42291233]]
# SIMILARITIES:
# (4287,)
# VECTORS:
# [array([1.1178385 , 0.01056387, 0.48088098, ..., 0.37275326, 1.9298282 ,
#        0.        ], dtype=float32), array([0.        , 2.1835783 , 0.17299852, ..., 0.09451447, 0.8450406 ,
#        0.        ], dtype=float32), array([0.11194851, 5.1044536 , 0.6943263 , ..., 0.        , 0.        ,
#        0.20145205], dtype=float32), array([0.        , 0.55481076, 1.5063937 , ..., 0.23668201, 0.31614333,
#        1.162719  ], dtype=float32), array([0.        , 0.20109892, 1.3414423 , ..., 1.3554119 , 0.        ,
#        0.3531357 ], dtype=float32), array([0.3840353 , 0.        , 1.0640663 , ..., 1.5807192 , 0.        ,
#        0.74220693], dtype=float32), array([0.        , 0.12137162, 0.        , ..., 0.4189059 , 0.        ,
#        0.        ], dtype=float32), array([1.5997123, 1.9817923, 4.451246 , ..., 1.7831733, 0.7108003,
#        0.0199666], dtype=float32), array([0.3120441, 0.0863374, 0.7124079, ..., 0.0277055, 0.1154585,
#        0.9984893], dtype=float32), array([0.        , 2.356631  , 5.8351164 , ..., 0.98355496, 0.        ,
#        1.1131907 ], dtype=float32), array([0.        , 0.8191548 , 2.8480463 , ..., 0.        , 0.4199377 ,
#        0.09146683], dtype=float32), array([0.        , 0.87854254, 0.4451886 , ..., 0.37497205, 0.        ,
#        0.06567872], dtype=float32), array([0.        , 0.51685834, 0.        , ..., 0.55413854, 0.25247177,
#        1.1322563 ], dtype=float32), array([0.        , 2.0724382 , 0.11579651, ..., 0.07037115, 0.        ,
#        0.        ], dtype=float32), array([1.5603317 , 0.        , 0.05807846, ..., 0.03954154, 1.2811222 ,
#        0.01419294], dtype=float32), array([0.        , 0.55382764, 1.4466782 , ..., 0.        , 0.        ,
#        0.44929278], dtype=float32), array([0.        , 1.5261599 , 0.        , ..., 0.        , 0.        ,
#        0.28244203], dtype=float32), array([0.48975307, 7.8360486 , 0.        , ..., 0.17316818, 0.        ,
#        0.42208385], dtype=float32), array([0.        , 1.3644713 , 0.6610776 , ..., 0.5735856 , 0.14756456,
#        0.        ], dtype=float32), array([0.56569976, 2.7430007 , 0.13488382, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.28101796, 2.3070025 , ..., 0.        , 0.8680891 ,
#        0.09108481], dtype=float32), array([0.        , 1.5403425 , 0.847407  , ..., 0.8138467 , 0.        ,
#        0.22304928], dtype=float32), array([0.66418266, 0.5275303 , 0.        , ..., 0.5309666 , 0.        ,
#        0.5620143 ], dtype=float32), array([0.        , 1.3605475 , 1.1982254 , ..., 0.340236  , 0.26953074,
#        0.3254788 ], dtype=float32), array([0.        , 2.3765972 , 0.32163075, ..., 1.1391196 , 0.        ,
#        0.04087127], dtype=float32), array([0.        , 2.3215308 , 2.1063874 , ..., 0.07560961, 0.        ,
#        0.20789237], dtype=float32), array([0.22773355, 0.        , 1.811208  , ..., 0.5056185 , 0.08461083,
#        0.        ], dtype=float32), array([0.        , 1.465037  , 0.1381879 , ..., 0.        , 0.        ,
#        0.32411307], dtype=float32), array([0.        , 0.262698  , 2.6245713 , ..., 0.19176616, 0.2373913 ,
#        1.2221445 ], dtype=float32), array([0.        , 2.7335548 , 0.01119024, ..., 0.19415814, 0.13241856,
#        1.1379395 ], dtype=float32), array([0.       , 0.       , 5.3539515, ..., 0.6674177, 0.       ,
#        0.       ], dtype=float32), array([0.        , 2.3530703 , 0.03456654, ..., 0.01698243, 0.01197637,
#        0.        ], dtype=float32), array([0.70808923, 1.4959126 , 0.1135855 , ..., 0.0551529 , 0.        ,
#        0.        ], dtype=float32), array([1.081753  , 2.286639  , 4.134403  , ..., 1.242451  , 0.        ,
#        0.49093977], dtype=float32), array([0.        , 0.        , 1.4890409 , ..., 6.428338  , 2.344895  ,
#        0.19155438], dtype=float32), array([0.9124062 , 3.2464545 , 0.12802598, ..., 0.        , 0.0478349 ,
#        0.15468146], dtype=float32), array([0.       , 2.9756227, 0.       , ..., 2.3552623, 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.8115188 , 0.        , ..., 0.83564854, 0.75346446,
#        0.        ], dtype=float32), array([0.        , 0.7949415 , 1.4906875 , ..., 0.        , 0.        ,
#        0.11412997], dtype=float32), array([0.3202253, 1.3666441, 0.       , ..., 0.5491828, 0.       ,
#        1.0115985], dtype=float32), array([0.        , 1.6141994 , 0.25184178, ..., 0.2505618 , 0.10185066,
#        0.43314898], dtype=float32), array([0.34223124, 1.5831925 , 0.80802524, ..., 1.0456064 , 0.5415908 ,
#        0.47451138], dtype=float32), array([0.3637765 , 0.        , 1.6248915 , ..., 0.10174353, 0.02770901,
#        0.24941267], dtype=float32), array([0.        , 1.9095201 , 5.1538315 , ..., 2.1623442 , 0.83764887,
#        0.0543761 ], dtype=float32), array([0.        , 1.3915905 , 0.07974847, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 2.4204578 , 1.7663631 , ..., 0.3898104 , 0.593473  ,
#        0.01918272], dtype=float32), array([0.        , 2.8440404 , 0.21361169, ..., 0.        , 0.2031677 ,
#        0.        ], dtype=float32), array([0.        , 0.40797737, 0.        , ..., 0.11162291, 0.34097502,
#        0.4618901 ], dtype=float32), array([0.       , 2.2498565, 5.07698  , ..., 0.5458013, 0.       ,
#        0.       ], dtype=float32), array([0.01934828, 4.7780623 , 4.3659964 , ..., 0.07099839, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.6416549 , 0.06441294, ..., 0.03041792, 0.        ,
#        0.00829394], dtype=float32), array([0.        , 0.00216955, 0.7567223 , ..., 1.0974314 , 0.44423866,
#        1.3484083 ], dtype=float32), array([0.        , 0.79199   , 1.7246349 , ..., 0.10899393, 0.74984   ,
#        0.        ], dtype=float32), array([0.00760911, 0.80268276, 0.96502036, ..., 0.        , 0.06530919,
#        0.98895663], dtype=float32), array([0.        , 0.07135784, 0.        , ..., 0.38010737, 0.        ,
#        0.06074638], dtype=float32), array([0.26576898, 0.        , 0.04944802, ..., 2.5152168 , 1.2878425 ,
#        2.1887982 ], dtype=float32), array([0.        , 1.3881035 , 1.1372774 , ..., 0.651656  , 0.46204248,
#        1.1560726 ], dtype=float32), array([0.        , 1.1405542 , 3.4666462 , ..., 0.        , 0.        ,
#        0.49093974], dtype=float32), array([0.        , 0.17564058, 0.14918768, ..., 1.0205457 , 0.06502035,
#        0.10918994], dtype=float32), array([0.01593953, 0.49550232, 0.        , ..., 0.9002042 , 0.05235731,
#        0.37297457], dtype=float32), array([0.02178633, 0.81970763, 0.        , ..., 0.        , 0.45623192,
#        1.9749382 ], dtype=float32), array([0.23509815, 1.68277   , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 1.2338663 , 0.57119   , ..., 0.03620972, 0.        ,
#        0.17361073], dtype=float32), array([0.33170253, 0.        , 0.7025117 , ..., 0.        , 0.1296916 ,
#        0.        ], dtype=float32), array([0.3234169 , 2.498152  , 0.8257615 , ..., 1.3579994 , 0.01885239,
#        0.3877056 ], dtype=float32), array([3.7524328 , 3.683398  , 0.23138864, ..., 0.        , 0.        ,
#        2.2156715 ], dtype=float32), array([1.020768  , 1.2281317 , 0.        , ..., 1.5389831 , 0.11033754,
#        1.220279  ], dtype=float32), array([0.        , 0.00636122, 0.        , ..., 0.24196261, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.6488925 , 0.05043781, ..., 0.04392903, 0.02443062,
#        0.08163012], dtype=float32), array([0.        , 0.60002375, 0.18245214, ..., 0.12504788, 0.3568482 ,
#        0.06400362], dtype=float32), array([0.       , 1.212194 , 1.7820522, ..., 1.3120635, 2.6890943,
#        0.       ], dtype=float32), array([0.        , 1.0205657 , 0.4933114 , ..., 0.62940776, 0.5800787 ,
#        0.        ], dtype=float32), array([0.        , 2.2494833 , 1.779454  , ..., 1.4703512 , 0.5082615 ,
#        0.30329913], dtype=float32), array([0.        , 0.8160689 , 2.3702445 , ..., 0.8324063 , 0.6069424 ,
#        0.17307611], dtype=float32), array([0.        , 0.5643246 , 0.7313342 , ..., 0.        , 1.1358043 ,
#        0.10487671], dtype=float32), array([0.        , 1.9340347 , 2.6813865 , ..., 2.3703156 , 0.10117226,
#        0.        ], dtype=float32), array([0.03365421, 0.4506783 , 0.69757813, ..., 0.7648628 , 0.00734623,
#        0.05473254], dtype=float32), array([0.        , 3.2177157 , 0.3522453 , ..., 0.01446068, 0.        ,
#        0.12781285], dtype=float32), array([0.        , 2.3329406 , 0.10201786, ..., 0.04628292, 0.16565143,
#        0.3118816 ], dtype=float32), array([2.1733952 , 2.7986665 , 2.5357924 , ..., 0.00345565, 0.        ,
#        0.        ], dtype=float32), array([1.7416272 , 0.        , 3.8810418 , ..., 0.13484213, 0.18110012,
#        1.0042194 ], dtype=float32), array([0.        , 1.0383017 , 0.06183306, ..., 0.15547948, 0.09558876,
#        0.        ], dtype=float32), array([0.        , 1.3955672 , 1.2089474 , ..., 0.01436354, 0.        ,
#        0.        ], dtype=float32), array([0.        , 2.4921746 , 0.65726185, ..., 0.        , 0.        ,
#        0.09601951], dtype=float32), array([0.        , 0.05622144, 0.        , ..., 0.        , 0.13377352,
#        0.00215538], dtype=float32), array([0.        , 3.461143  , 0.64303905, ..., 1.8677549 , 2.3204148 ,
#        0.        ], dtype=float32), array([3.7377700e-01, 1.3529582e+00, 0.0000000e+00, ..., 1.6505052e+00,
#        2.3862720e-04, 9.2573041e-01], dtype=float32), array([0.65822077, 1.2861663 , 0.        , ..., 1.6946149 , 2.0974538 ,
#        1.8850341 ], dtype=float32), array([0.        , 0.8414143 , 0.5490284 , ..., 1.3842182 , 0.01424672,
#        0.41158766], dtype=float32), array([0.0125649 , 1.9478563 , 0.84519994, ..., 0.3232317 , 0.6638496 ,
#        0.6700213 ], dtype=float32), array([0.29895324, 4.2503734 , 0.2868964 , ..., 0.        , 0.        ,
#        0.21152659], dtype=float32), array([0.5775504 , 0.1928322 , 3.9225492 , ..., 1.1618135 , 0.0418734 ,
#        0.76592934], dtype=float32), array([0.08289121, 4.0084553 , 0.25351745, ..., 1.0349149 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.13168429, 0.70700765, ..., 1.5893036 , 0.790946  ,
#        0.4979551 ], dtype=float32), array([0.14196244, 1.3671956 , 0.8285781 , ..., 0.12243494, 0.        ,
#        0.760236  ], dtype=float32), array([0.       , 5.5493584, 0.5074393, ..., 0.       , 0.       ,
#        2.0818853], dtype=float32), array([0.51914835, 0.6045773 , 0.39707184, ..., 0.18919705, 1.3120228 ,
#        0.4774992 ], dtype=float32), array([0.04998119, 0.08512042, 0.        , ..., 0.36132216, 0.        ,
#        0.16929282], dtype=float32), array([1.072634  , 1.4867437 , 0.        , ..., 0.7855358 , 1.1233233 ,
#        0.15464641], dtype=float32), array([0.        , 3.7830143 , 2.250912  , ..., 0.80616647, 0.        ,
#        0.957452  ], dtype=float32), array([1.7891686 , 1.3368509 , 0.51528835, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.48178   , 3.2850316 , 0.56912744, ..., 0.01875432, 0.09095667,
#        0.35255206], dtype=float32), array([0.        , 1.0623916 , 0.15921906, ..., 3.1280515 , 2.2320578 ,
#        0.        ], dtype=float32), array([0.46065798, 5.410343  , 0.47037524, ..., 0.        , 0.55013907,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.5857252, ..., 0.       , 0.       ,
#        1.0248156], dtype=float32), array([0.        , 0.25258043, 0.40666375, ..., 0.49904776, 0.04003448,
#        0.        ], dtype=float32), array([0.0834473 , 0.05819681, 0.        , ..., 0.28681606, 0.52560484,
#        0.        ], dtype=float32), array([0.        , 0.02159065, 1.837584  , ..., 0.34167486, 0.        ,
#        0.        ], dtype=float32), array([0.0293943 , 0.11315911, 0.47033235, ..., 1.2841535 , 0.01862581,
#        0.        ], dtype=float32), array([0.        , 0.21419165, 0.41526306, ..., 0.29858035, 0.02912097,
#        0.00072458], dtype=float32), array([0.02978624, 6.5972023 , 1.5916486 , ..., 0.03631928, 0.02493941,
#        0.3209981 ], dtype=float32), array([0.01682338, 0.74153364, 6.021304  , ..., 1.164131  , 0.14294459,
#        0.07761812], dtype=float32), array([0.        , 0.15838079, 1.5769322 , ..., 0.3897355 , 0.02323613,
#        0.        ], dtype=float32), array([0.3757739 , 0.60876757, 0.5456487 , ..., 0.02631671, 0.        ,
#        0.18546179], dtype=float32), array([0.        , 1.397337  , 0.9018223 , ..., 0.        , 0.27831703,
#        0.13153502], dtype=float32), array([0.        , 1.100888  , 0.01206219, ..., 0.        , 0.        ,
#        0.3400204 ], dtype=float32)]
# USER PROFILE:
# [[0.23930019 1.4698871  1.0594983  ... 0.5819055  0.31175172 0.36432242]]
# SIMILARITIES:
# (4287,)
# VECTORS:
# [array([0.876672  , 0.0419229 , 0.17447141, ..., 0.09966754, 0.20095247,
#        0.76563096], dtype=float32), array([0.       , 1.0098953, 0.       , ..., 0.       , 0.       ,
#        1.1440508], dtype=float32), array([0.4545265 , 0.25139728, 0.02663058, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([1.1499264 , 0.82248944, 0.8096087 , ..., 0.20168518, 0.        ,
#        1.0863385 ], dtype=float32), array([0.        , 0.5298286 , 0.29197693, ..., 0.        , 0.14711314,
#        0.82335615], dtype=float32), array([0.9124062 , 3.2464545 , 0.12802598, ..., 0.        , 0.0478349 ,
#        0.15468146], dtype=float32), array([0.        , 3.6409361 , 0.        , ..., 2.5113943 , 0.37010515,
#        0.        ], dtype=float32), array([0.06746709, 0.20407207, 1.533705  , ..., 0.53753746, 0.92954767,
#        0.        ], dtype=float32), array([0.00362244, 0.        , 0.82107866, ..., 0.        , 0.1243109 ,
#        0.26179948], dtype=float32), array([0.66418266, 0.5275303 , 0.        , ..., 0.5309666 , 0.        ,
#        0.5620143 ], dtype=float32), array([1.6217778 , 4.803156  , 0.        , ..., 0.        , 0.        ,
#        0.13836521], dtype=float32), array([0.18838751, 0.        , 0.95013493, ..., 0.7388371 , 1.3932115 ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.36139292, ..., 0.        , 0.04899034,
#        0.        ], dtype=float32), array([1.4021165 , 0.20115733, 0.        , ..., 0.        , 0.17612198,
#        0.60850763], dtype=float32), array([0.1471915 , 0.8571359 , 0.05706006, ..., 0.44847304, 0.        ,
#        0.        ], dtype=float32), array([0.349513 , 0.       , 1.0027791, ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.       , 2.1275928, 0.74932  , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.09127676, 0.6898288 , 0.        , ..., 0.00383599, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.20109892, 1.3414423 , ..., 1.3554119 , 0.        ,
#        0.3531357 ], dtype=float32), array([0.        , 2.6707275 , 2.0274067 , ..., 2.0576153 , 0.        ,
#        0.01307551], dtype=float32), array([0.        , 0.7353879 , 0.        , ..., 0.17558865, 0.34163505,
#        0.01507702], dtype=float32), array([0.3840353 , 0.        , 1.0640663 , ..., 1.5807192 , 0.        ,
#        0.74220693], dtype=float32), array([0.        , 0.2675177 , 2.5299478 , ..., 1.6727713 , 0.8179436 ,
#        0.25348455], dtype=float32), array([0.        , 0.55382764, 1.4466782 , ..., 0.        , 0.        ,
#        0.44929278], dtype=float32), array([0.        , 0.55481076, 1.5063937 , ..., 0.23668201, 0.31614333,
#        1.162719  ], dtype=float32), array([0.09298299, 4.617673  , 0.84960544, ..., 0.07666521, 0.        ,
#        0.75441104], dtype=float32), array([0.10686539, 0.00758583, 0.03288287, ..., 0.03171243, 0.23486549,
#        0.72598076], dtype=float32), array([1.6947608 , 4.5682406 , 0.33567393, ..., 3.5227509 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 5.367365  , ..., 0.13735238, 2.2047868 ,
#        0.38145328], dtype=float32), array([0.8746911 , 1.6681584 , 1.9620752 , ..., 0.        , 0.74147844,
#        1.4104775 ], dtype=float32), array([0.       , 2.0713048, 1.5240899, ..., 0.8756991, 0.       ,
#        0.       ], dtype=float32), array([0.70808923, 1.4959126 , 0.1135855 , ..., 0.0551529 , 0.        ,
#        0.        ], dtype=float32), array([0.23452793, 2.6433015 , 0.        , ..., 0.18333367, 0.05433857,
#        0.        ], dtype=float32), array([2.0049715 , 4.2237163 , 0.42267424, ..., 2.7998648 , 0.        ,
#        1.1637821 ], dtype=float32), array([1.5255092, 1.5088184, 1.3000134, ..., 0.       , 0.6896452,
#        0.3938548], dtype=float32), array([0.        , 2.8440404 , 0.21361169, ..., 0.        , 0.2031677 ,
#        0.        ], dtype=float32), array([0.        , 1.5403425 , 0.847407  , ..., 0.8138467 , 0.        ,
#        0.22304928], dtype=float32), array([0.50999075, 0.46842787, 0.38994053, ..., 0.18619739, 0.5390147 ,
#        0.2379742 ], dtype=float32), array([0.49983478, 0.        , 0.9168259 , ..., 0.7238782 , 1.144922  ,
#        1.4055283 ], dtype=float32), array([0.        , 0.55489594, 0.        , ..., 0.5471728 , 1.0438669 ,
#        0.5011556 ], dtype=float32), array([1.0647752 , 1.6243844 , 0.        , ..., 1.9068291 , 0.30745387,
#        0.9692806 ], dtype=float32), array([0.        , 0.74442315, 0.96939373, ..., 1.3761382 , 0.26659247,
#        0.        ], dtype=float32), array([0.1350866 , 7.200062  , 0.48848745, ..., 0.        , 0.        ,
#        1.9330359 ], dtype=float32), array([0.02758033, 2.5656772 , 1.5973232 , ..., 0.        , 0.        ,
#        1.8912109 ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.1440508, 0.       ,
#        0.8857777], dtype=float32), array([0.669042  , 1.862792  , 0.61266667, ..., 2.0445223 , 0.18829745,
#        1.4059831 ], dtype=float32), array([0.01558265, 3.4073348 , 0.54474485, ..., 1.0317996 , 0.        ,
#        0.06740557], dtype=float32), array([0.        , 0.79199   , 1.7246349 , ..., 0.10899393, 0.74984   ,
#        0.        ], dtype=float32), array([0.       , 3.9145918, 1.5890789, ..., 0.6214656, 0.       ,
#        0.1541242], dtype=float32), array([0.        , 1.3605475 , 1.1982254 , ..., 0.340236  , 0.26953074,
#        0.3254788 ], dtype=float32), array([0.        , 0.1933506 , 0.01327796, ..., 0.        , 0.        ,
#        0.00922991], dtype=float32), array([0.        , 1.5696023 , 2.562624  , ..., 0.15073927, 0.        ,
#        0.19320466], dtype=float32), array([0.17112784, 1.111358  , 3.4670713 , ..., 0.8000211 , 2.3974726 ,
#        0.        ], dtype=float32), array([0.        , 2.3530703 , 0.03456654, ..., 0.01698243, 0.01197637,
#        0.        ], dtype=float32), array([0.1378997 , 0.18581475, 1.238534  , ..., 1.1971133 , 0.2891253 ,
#        0.28095025], dtype=float32), array([0.0395807 , 1.8214169 , 0.        , ..., 0.17698695, 0.04658057,
#        0.11970987], dtype=float32), array([1.5125586e-02, 0.0000000e+00, 2.4769814e+00, ..., 2.2061504e-03,
#        0.0000000e+00, 7.6304817e-01], dtype=float32), array([0.        , 0.        , 1.7079042 , ..., 0.7871828 , 3.1074686 ,
#        0.43823132], dtype=float32), array([0.3621661 , 0.42468792, 0.05580027, ..., 0.08609359, 1.8502548 ,
#        0.26832217], dtype=float32), array([0.        , 3.461143  , 0.64303905, ..., 1.8677549 , 2.3204148 ,
#        0.        ], dtype=float32), array([0.12617353, 0.9927434 , 0.290285  , ..., 0.00605096, 0.        ,
#        0.36049157], dtype=float32), array([0.0131133, 1.7068899, 0.       , ..., 0.3847596, 0.7517307,
#        0.       ], dtype=float32), array([0.        , 3.8552256 , 0.27888373, ..., 0.        , 0.        ,
#        1.2488348 ], dtype=float32), array([0.        , 2.0647333 , 0.06206944, ..., 0.4651918 , 0.        ,
#        0.38918355], dtype=float32), array([3.4890065 , 3.4308474 , 1.7246819 , ..., 1.6831157 , 0.87872225,
#        0.44585633], dtype=float32), array([0.14641486, 5.0233426 , 0.        , ..., 0.        , 0.        ,
#        0.4345837 ], dtype=float32), array([0.       , 1.114932 , 0.       , ..., 0.       , 0.       ,
#        0.2687115], dtype=float32), array([0.02568135, 4.1601143 , 0.00720204, ..., 0.        , 0.        ,
#        0.49221608], dtype=float32), array([9.9984929e-04, 3.1529660e+00, 4.2772174e-01, ..., 1.1368660e-01,
#        0.0000000e+00, 0.0000000e+00], dtype=float32), array([0.        , 0.03266485, 0.13747865, ..., 0.        , 0.8543591 ,
#        0.4548059 ], dtype=float32), array([0.        , 0.9317951 , 2.3677387 , ..., 0.        , 0.86710525,
#        1.2858281 ], dtype=float32), array([0.30620357, 0.28771475, 1.6843296 , ..., 0.4169732 , 0.11833359,
#        0.11492907], dtype=float32), array([0.01193457, 0.84704226, 0.        , ..., 0.        , 0.26396912,
#        0.51866984], dtype=float32), array([0.195676  , 3.3359585 , 0.38071644, ..., 0.        , 1.4699199 ,
#        0.        ], dtype=float32), array([0.        , 0.7949415 , 1.4906875 , ..., 0.        , 0.        ,
#        0.11412997], dtype=float32), array([0.       , 2.9756227, 0.       , ..., 2.3552623, 0.       ,
#        0.       ], dtype=float32), array([2.4384062 , 3.00517   , 0.        , ..., 0.        , 0.        ,
#        0.15666503], dtype=float32), array([0.0055617 , 0.71385676, 2.1231747 , ..., 0.55800974, 0.        ,
#        0.24945268], dtype=float32), array([1.298845  , 4.588891  , 0.4184333 , ..., 0.5073236 , 0.04937872,
#        0.298684  ], dtype=float32), array([0.        , 0.60002375, 0.18245214, ..., 0.12504788, 0.3568482 ,
#        0.06400362], dtype=float32), array([0.        , 0.08808418, 0.33815765, ..., 0.        , 0.31456628,
#        0.        ], dtype=float32), array([0.        , 3.841351  , 0.19834304, ..., 0.03070182, 0.01618457,
#        0.35447448], dtype=float32), array([0.3202253, 1.3666441, 0.       , ..., 0.5491828, 0.       ,
#        1.0115985], dtype=float32), array([0.        , 1.6141994 , 0.25184178, ..., 0.2505618 , 0.10185066,
#        0.43314898], dtype=float32), array([0.        , 2.2713351 , 0.02005878, ..., 0.        , 0.        ,
#        0.11084874], dtype=float32), array([0.        , 0.31160638, 4.2138405 , ..., 0.        , 1.5679661 ,
#        0.5755062 ], dtype=float32), array([0.        , 3.236144  , 0.36135656, ..., 0.34295422, 0.2500574 ,
#        0.16821273], dtype=float32), array([0.        , 4.275688  , 0.02590855, ..., 0.28066444, 0.        ,
#        0.05334968], dtype=float32), array([1.3517034 , 4.214362  , 0.07311051, ..., 0.05991632, 0.        ,
#        0.01548263], dtype=float32), array([0.        , 2.6938627 , 0.        , ..., 0.        , 0.41222075,
#        0.27199692], dtype=float32), array([0.        , 0.9304727 , 0.        , ..., 0.15298751, 0.        ,
#        0.4530617 ], dtype=float32), array([0.11734231, 0.        , 1.080287  , ..., 1.7120678 , 0.8136407 ,
#        0.358653  ], dtype=float32), array([0.        , 0.        , 2.355048  , ..., 1.4096029 , 0.17435545,
#        0.01061503], dtype=float32), array([0.        , 0.        , 0.326608  , ..., 0.16419557, 0.        ,
#        0.09025536], dtype=float32), array([0.        , 2.0697124 , 0.8794489 , ..., 0.32067612, 2.1749282 ,
#        0.21230434], dtype=float32), array([0.03806311, 2.1237252 , 0.        , ..., 0.        , 0.01415265,
#        0.07403077], dtype=float32), array([0.        , 0.08203703, 0.01111519, ..., 0.48541385, 0.        ,
#        0.        ], dtype=float32), array([0.02978624, 6.5972023 , 1.5916486 , ..., 0.03631928, 0.02493941,
#        0.3209981 ], dtype=float32), array([1.7843091, 0.       , 0.5911379, ..., 1.330651 , 0.940753 ,
#        0.       ], dtype=float32), array([0.0293943 , 0.11315911, 0.47033235, ..., 1.2841535 , 0.01862581,
#        0.        ], dtype=float32), array([0.0494727, 0.       , 0.6776254, ..., 0.       , 0.6206548,
#        1.2943206], dtype=float32), array([0.        , 0.02159065, 1.837584  , ..., 0.34167486, 0.        ,
#        0.        ], dtype=float32), array([0.        , 2.3329406 , 0.10201786, ..., 0.04628292, 0.16565143,
#        0.3118816 ], dtype=float32), array([0.       , 2.687279 , 0.3193969, ..., 0.       , 0.       ,
#        0.1411177], dtype=float32), array([2.9857957e-01, 5.1883388e+00, 2.3662781e-03, ..., 1.4028819e+00,
#        0.0000000e+00, 6.4493960e-01], dtype=float32), array([1.1239259 , 2.5943635 , 0.02274443, ..., 0.44582033, 0.        ,
#        0.07862481], dtype=float32), array([0.        , 0.        , 0.27224356, ..., 0.        , 0.37509453,
#        0.12177716], dtype=float32), array([0.        , 1.3955672 , 1.2089474 , ..., 0.01436354, 0.        ,
#        0.        ], dtype=float32), array([0.48178   , 3.2850316 , 0.56912744, ..., 0.01875432, 0.09095667,
#        0.35255206], dtype=float32), array([0.        , 3.625144  , 0.98663074, ..., 0.        , 0.36984152,
#        0.02439346], dtype=float32), array([0.47499523, 0.2784737 , 0.35175455, ..., 0.07276928, 1.8173372 ,
#        0.2145231 ], dtype=float32), array([0.48780683, 2.8542159 , 0.15307666, ..., 0.18218736, 0.61683613,
#        0.        ], dtype=float32), array([0.0125649 , 1.9478563 , 0.84519994, ..., 0.3232317 , 0.6638496 ,
#        0.6700213 ], dtype=float32)]
# USER PROFILE:
# [[0.29965714 1.7026309  0.74101824 ... 0.4658173  0.36044106 0.36019573]]
# SIMILARITIES:
# (4287,)
# VECTORS:
# [array([0.37490708, 0.90572864, 0.34034437, ..., 0.5352442 , 0.14322768,
#        1.2958804 ], dtype=float32), array([0.       , 0.1409731, 2.1059716, ..., 0.2103072, 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.4194891 , 1.7885784 , ..., 0.03261256, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.36468583, 1.2149708 , ..., 1.12945   , 0.48590484,
#        1.2902982 ], dtype=float32), array([0.        , 0.89748037, 0.        , ..., 0.        , 0.        ,
#        0.01448037], dtype=float32), array([1.1953021 , 2.1679003 , 0.        , ..., 0.        , 0.        ,
#        0.31932825], dtype=float32), array([1.020768  , 1.2281317 , 0.        , ..., 1.5389831 , 0.11033754,
#        1.220279  ], dtype=float32), array([0.        , 1.0383017 , 0.06183306, ..., 0.15547948, 0.09558876,
#        0.        ], dtype=float32), array([0.        , 0.40797737, 0.        , ..., 0.11162291, 0.34097502,
#        0.4618901 ], dtype=float32), array([0.        , 4.15434   , 0.1961275 , ..., 0.32595024, 0.3342483 ,
#        0.11338483], dtype=float32), array([0.6718086 , 0.5182246 , 1.1873323 , ..., 0.86013293, 0.        ,
#        0.58848923], dtype=float32), array([0.        , 1.2940708 , 0.96636957, ..., 2.7368689 , 0.603891  ,
#        0.26222664], dtype=float32), array([2.3146386 , 0.        , 2.1377168 , ..., 0.03108668, 1.7124882 ,
#        0.164928  ], dtype=float32), array([0.        , 1.0178087 , 0.        , ..., 0.        , 1.4771385 ,
#        0.04256159], dtype=float32), array([0.50999075, 0.46842787, 0.38994053, ..., 0.18619739, 0.5390147 ,
#        0.2379742 ], dtype=float32), array([0.        , 0.        , 2.355048  , ..., 1.4096029 , 0.17435545,
#        0.01061503], dtype=float32), array([0.8821311, 1.2913475, 3.4175649, ..., 3.7825537, 5.1032696,
#        0.       ], dtype=float32), array([1.1560738 , 2.4962857 , 0.11975893, ..., 0.4165997 , 0.        ,
#        1.1141169 ], dtype=float32), array([0.        , 0.51685834, 0.        , ..., 0.55413854, 0.25247177,
#        1.1322563 ], dtype=float32), array([0.        , 2.857733  , 1.4408051 , ..., 0.01137459, 0.        ,
#        0.        ], dtype=float32), array([0.01019283, 0.0935325 , 3.0099788 , ..., 0.0498268 , 0.33620933,
#        2.0929823 ], dtype=float32), array([0.        , 0.67263657, 1.3441193 , ..., 2.6107824 , 0.        ,
#        0.        ], dtype=float32), array([0.0580334 , 0.04926348, 2.0608623 , ..., 1.7257802 , 1.5156733 ,
#        0.        ], dtype=float32), array([0.01088719, 3.3439114 , 0.16579336, ..., 0.36038446, 0.05537096,
#        0.12472183], dtype=float32), array([0.        , 0.        , 5.367365  , ..., 0.13735238, 2.2047868 ,
#        0.38145328], dtype=float32), array([0.        , 0.42492896, 0.19053872, ..., 0.04716264, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.55489594, 0.        , ..., 0.5471728 , 1.0438669 ,
#        0.5011556 ], dtype=float32), array([0.13121587, 4.008071  , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 1.2221754 , 0.        , ..., 0.        , 0.05506431,
#        0.6853037 ], dtype=float32), array([0.04128091, 0.6748657 , 1.9057314 , ..., 1.0310946 , 0.37123924,
#        0.        ], dtype=float32), array([0.        , 0.2311672 , 0.21158737, ..., 0.29830927, 0.00335075,
#        0.2697688 ], dtype=float32), array([0.        , 3.062419  , 1.0918136 , ..., 0.8268931 , 0.17442088,
#        0.18540129], dtype=float32), array([0.        , 0.03334819, 0.93423307, ..., 0.7262835 , 0.15484624,
#        0.45600036], dtype=float32), array([0.        , 2.559702  , 0.5993284 , ..., 0.07758299, 0.        ,
#        0.07473422], dtype=float32), array([0.        , 1.1324893 , 0.18132657, ..., 0.3931681 , 0.03344984,
#        0.21390378], dtype=float32), array([0.        , 1.6153687 , 2.8000376 , ..., 0.79126906, 0.09855834,
#        0.        ], dtype=float32), array([0.22068782, 0.28052735, 3.0423052 , ..., 0.9007915 , 0.04436579,
#        0.2634313 ], dtype=float32), array([0.        , 0.        , 0.5870567 , ..., 0.09966376, 0.        ,
#        0.        ], dtype=float32), array([0.       , 2.2498565, 5.07698  , ..., 0.5458013, 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.82501006, 3.3153877 , ..., 0.48524237, 0.863975  ,
#        0.01206995], dtype=float32), array([0.        , 0.06494883, 0.80806404, ..., 0.58640945, 0.26315707,
#        0.        ], dtype=float32), array([0.        , 0.5429409 , 0.7621986 , ..., 0.40715033, 0.        ,
#        0.51661265], dtype=float32), array([0.        , 3.2177157 , 0.3522453 , ..., 0.01446068, 0.        ,
#        0.12781285], dtype=float32), array([0.6541429 , 0.        , 2.220424  , ..., 2.00557   , 0.0028198 ,
#        0.12010895], dtype=float32), array([0.07393056, 3.761234  , 0.90737283, ..., 2.5474193 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 1.6592274 , 0.        , ..., 0.7309985 , 0.        ,
#        0.24105056], dtype=float32), array([0.05920174, 0.9056858 , 0.94460607, ..., 0.21476158, 0.        ,
#        0.25676855], dtype=float32), array([0.        , 0.12180494, 0.        , ..., 0.6021139 , 0.        ,
#        0.25189477], dtype=float32), array([0.6683961, 1.3072119, 0.8244344, ..., 0.6380813, 0.       ,
#        0.       ], dtype=float32), array([0.        , 1.1664425 , 0.91639376, ..., 0.9877754 , 0.17240162,
#        0.7534834 ], dtype=float32), array([0.       , 2.67137  , 2.5199122, ..., 0.7539791, 0.       ,
#        1.6871482], dtype=float32), array([0.        , 0.        , 0.        , ..., 0.1983733 , 0.07632093,
#        0.3959223 ], dtype=float32), array([0.        , 0.96651804, 0.53365546, ..., 1.0918982 , 0.33788097,
#        0.10314651], dtype=float32), array([0.2288581 , 4.9403057 , 2.0617704 , ..., 0.12784122, 0.20146227,
#        0.22843769], dtype=float32), array([0.        , 3.779396  , 0.        , ..., 0.23872465, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.12647976, 0.        , ..., 0.        , 1.4822068 ,
#        1.8823625 ], dtype=float32), array([0.01598813, 2.2440252 , 1.7233926 , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.0834473 , 0.05819681, 0.        , ..., 0.28681606, 0.52560484,
#        0.        ], dtype=float32), array([0.03051749, 0.        , 0.933468  , ..., 0.8048816 , 0.9889779 ,
#        0.43241692], dtype=float32), array([1.6277299 , 3.607679  , 0.42188382, ..., 0.38729623, 0.62986875,
#        0.7286366 ], dtype=float32), array([0.       , 0.       , 1.4598963, ..., 2.2443283, 0.       ,
#        0.       ], dtype=float32), array([0.        , 1.8546872 , 0.        , ..., 0.21172321, 0.        ,
#        0.        ], dtype=float32), array([0.669042  , 1.862792  , 0.61266667, ..., 2.0445223 , 0.18829745,
#        1.4059831 ], dtype=float32), array([0.12695056, 0.37704813, 4.108245  , ..., 1.014652  , 0.8322652 ,
#        0.        ], dtype=float32), array([0.        , 0.89041054, 0.        , ..., 2.7071848 , 1.3390042 ,
#        0.6241692 ], dtype=float32), array([0.        , 0.57358944, 1.7259576 , ..., 0.12398338, 0.        ,
#        0.11879182], dtype=float32), array([1.7195554 , 4.229791  , 0.        , ..., 0.57296747, 0.03048673,
#        0.        ], dtype=float32), array([0.        , 0.13168429, 0.70700765, ..., 1.5893036 , 0.790946  ,
#        0.4979551 ], dtype=float32), array([0.        , 1.3917078 , 0.84117675, ..., 0.        , 0.        ,
#        1.5755887 ], dtype=float32), array([0.71409595, 3.4948158 , 1.1952116 , ..., 0.8356454 , 0.        ,
#        1.4790137 ], dtype=float32), array([0.01558265, 3.4073348 , 0.54474485, ..., 1.0317996 , 0.        ,
#        0.06740557], dtype=float32), array([0.        , 0.35249653, 0.        , ..., 0.02826831, 0.        ,
#        0.11308598], dtype=float32), array([0.        , 1.0249269 , 0.53983015, ..., 0.        , 0.2079499 ,
#        0.4014459 ], dtype=float32), array([1.3168188, 2.1362948, 0.       , ..., 1.1676753, 1.192756 ,
#        2.77816  ], dtype=float32), array([0.10830722, 1.2335029 , 3.1582353 , ..., 0.23245941, 1.3597829 ,
#        2.3889081 ], dtype=float32), array([0.03392129, 0.6995528 , 1.6516432 , ..., 0.        , 0.75072944,
#        0.07423171], dtype=float32), array([0.        , 0.28850448, 2.038965  , ..., 0.00292227, 0.22905058,
#        0.91713095], dtype=float32), array([0.07789342, 1.6535884 , 3.468924  , ..., 0.        , 0.        ,
#        0.29390773], dtype=float32), array([0.        , 0.        , 0.21610567, ..., 0.10409856, 0.1470789 ,
#        0.        ], dtype=float32), array([1.182314  , 3.559969  , 2.6089618 , ..., 0.        , 0.79998535,
#        1.0064416 ], dtype=float32), array([0.32854706, 1.7396114 , 0.75699043, ..., 0.        , 0.        ,
#        0.21820608], dtype=float32), array([0.        , 2.4378564 , 0.04723327, ..., 0.6131058 , 1.7013222 ,
#        1.2329398 ], dtype=float32), array([0.03646067, 0.20765674, 0.50764644, ..., 1.4235036 , 0.58012986,
#        0.2941432 ], dtype=float32), array([0.        , 0.1933506 , 0.01327796, ..., 0.        , 0.        ,
#        0.00922991], dtype=float32), array([0.       , 0.688732 , 2.4793024, ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 0.41483593, 1.5659024 , ..., 0.33645374, 0.03926078,
#        0.        ], dtype=float32), array([0.00793242, 0.12665932, 1.1075642 , ..., 0.04285579, 0.51284194,
#        0.00352681], dtype=float32), array([0.03276723, 0.        , 0.        , ..., 0.45019898, 0.        ,
#        0.19716343], dtype=float32), array([0.       , 0.       , 1.8539541, ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.09062393, 0.39353812, 1.2538097 , ..., 1.8613318 , 0.0151182 ,
#        2.851099  ], dtype=float32), array([0.        , 0.        , 0.51589894, ..., 0.5279059 , 0.        ,
#        1.8917136 ], dtype=float32), array([1.0786438 , 1.4648534 , 2.3969455 , ..., 0.07357293, 0.18115097,
#        0.        ], dtype=float32), array([0.        , 0.1489659 , 0.8389248 , ..., 0.28402734, 0.41252622,
#        0.00422043], dtype=float32), array([0.        , 0.9325993 , 0.00842418, ..., 0.09329849, 0.        ,
#        0.4451968 ], dtype=float32), array([0.15754133, 0.53456354, 0.16070345, ..., 0.5707295 , 4.422867  ,
#        0.        ], dtype=float32), array([0.        , 2.91174   , 2.3195384 , ..., 0.6283005 , 0.01551494,
#        0.        ], dtype=float32), array([0.        , 0.5485474 , 2.8211808 , ..., 1.0420711 , 0.33273244,
#        0.88873374], dtype=float32), array([1.7843091, 0.       , 0.5911379, ..., 1.330651 , 0.940753 ,
#        0.       ], dtype=float32), array([0.       , 1.3795784, 1.6436703, ..., 0.       , 0.       ,
#        1.4607949], dtype=float32), array([0.        , 0.01634309, 0.4121095 , ..., 0.        , 0.27856842,
#        1.7028791 ], dtype=float32), array([0.25283659, 0.3337198 , 0.5533414 , ..., 0.        , 0.        ,
#        0.76372564], dtype=float32), array([0.01318801, 0.17316952, 0.6382584 , ..., 0.12209148, 0.04488068,
#        0.01022964], dtype=float32), array([0.        , 0.2970554 , 0.        , ..., 0.58931816, 0.        ,
#        0.12721613], dtype=float32), array([0.0000000e+00, 3.2112305e+00, 3.4850488e+00, ..., 0.0000000e+00,
#        0.0000000e+00, 3.0928908e-03], dtype=float32), array([0.        , 0.39761522, 0.72693056, ..., 0.53139603, 0.85639906,
#        0.19121237], dtype=float32), array([0.7119051 , 2.2274928 , 0.62424034, ..., 0.823306  , 1.735734  ,
#        0.7192577 ], dtype=float32), array([0.        , 1.0095565 , 0.01364405, ..., 1.0919278 , 1.9322288 ,
#        0.10153659], dtype=float32), array([0.       , 2.560784 , 0.7118288, ..., 3.7634742, 0.       ,
#        0.7938395], dtype=float32), array([0.4656882 , 0.        , 0.23644745, ..., 0.795816  , 0.        ,
#        1.4843748 ], dtype=float32), array([0.8937794 , 4.812182  , 0.73252654, ..., 0.35551488, 0.01869787,
#        0.        ], dtype=float32), array([0.        , 3.4625788 , 0.        , ..., 0.03488024, 0.        ,
#        0.00721424], dtype=float32), array([0.        , 0.2760244 , 1.5876846 , ..., 0.24307606, 0.4766305 ,
#        0.32908887], dtype=float32), array([0.        , 1.1405542 , 3.4666462 , ..., 0.        , 0.        ,
#        0.49093974], dtype=float32), array([0.        , 2.3530703 , 0.03456654, ..., 0.01698243, 0.01197637,
#        0.        ], dtype=float32), array([1.0218945 , 3.0651588 , 0.        , ..., 0.01085252, 0.        ,
#        0.5694881 ], dtype=float32), array([0.00805454, 3.0853906 , 0.        , ..., 0.04496048, 1.1819239 ,
#        0.        ], dtype=float32), array([0.09947991, 0.30409884, 0.        , ..., 1.0063453 , 0.27356172,
#        0.        ], dtype=float32), array([1.2901552 , 0.32292125, 1.448254  , ..., 2.6679146 , 0.        ,
#        0.39967132], dtype=float32)]
# USER PROFILE:
# [[0.22269845 1.2601342  1.0675242  ... 0.62368387 0.39696565 0.44227448]]
# SIMILARITIES:
# (4287,)
# VECTORS:
# [array([0.05957682, 1.1103563 , 1.3551004 , ..., 0.7633083 , 0.00679227,
#        0.03837556], dtype=float32), array([0.34223124, 1.5831925 , 0.80802524, ..., 1.0456064 , 0.5415908 ,
#        0.47451138], dtype=float32), array([0.        , 3.6409361 , 0.        , ..., 2.5113943 , 0.37010515,
#        0.        ], dtype=float32), array([0.9124062 , 3.2464545 , 0.12802598, ..., 0.        , 0.0478349 ,
#        0.15468146], dtype=float32), array([0.        , 0.8115188 , 0.        , ..., 0.83564854, 0.75346446,
#        0.        ], dtype=float32), array([0.       , 2.9756227, 0.       , ..., 2.3552623, 0.       ,
#        0.       ], dtype=float32), array([0.3637765 , 0.        , 1.6248915 , ..., 0.10174353, 0.02770901,
#        0.24941267], dtype=float32), array([0.        , 0.7949415 , 1.4906875 , ..., 0.        , 0.        ,
#        0.11412997], dtype=float32), array([0.        , 1.6141994 , 0.25184178, ..., 0.2505618 , 0.10185066,
#        0.43314898], dtype=float32), array([0.3202253, 1.3666441, 0.       , ..., 0.5491828, 0.       ,
#        1.0115985], dtype=float32), array([1.072634  , 1.4867437 , 0.        , ..., 0.7855358 , 1.1233233 ,
#        0.15464641], dtype=float32), array([0.66418266, 0.5275303 , 0.        , ..., 0.5309666 , 0.        ,
#        0.5620143 ], dtype=float32), array([0.        , 0.23156217, 0.        , ..., 2.435433  , 0.        ,
#        0.03682983], dtype=float32), array([0.30620357, 0.28771475, 1.6843296 , ..., 0.4169732 , 0.11833359,
#        0.11492907], dtype=float32), array([0.06746709, 0.20407207, 1.533705  , ..., 0.53753746, 0.92954767,
#        0.        ], dtype=float32), array([0.01157491, 0.        , 0.66318196, ..., 0.49965972, 0.42274117,
#        0.1832974 ], dtype=float32), array([0.3840353 , 0.        , 1.0640663 , ..., 1.5807192 , 0.        ,
#        0.74220693], dtype=float32), array([0.        , 1.3605475 , 1.1982254 , ..., 0.340236  , 0.26953074,
#        0.3254788 ], dtype=float32), array([0.11734231, 0.        , 1.080287  , ..., 1.7120678 , 0.8136407 ,
#        0.358653  ], dtype=float32), array([1.182314  , 3.559969  , 2.6089618 , ..., 0.        , 0.79998535,
#        1.0064416 ], dtype=float32), array([0.07983951, 0.79610306, 1.7116795 , ..., 1.2266085 , 0.        ,
#        0.53923553], dtype=float32), array([0.        , 0.8262018 , 0.85560364, ..., 0.40489924, 0.        ,
#        0.33911526], dtype=float32), array([0.08130962, 0.28091675, 5.9041324 , ..., 0.4220616 , 1.102952  ,
#        1.5667236 ], dtype=float32), array([0.       , 3.9145918, 1.5890789, ..., 0.6214656, 0.       ,
#        0.1541242], dtype=float32), array([0.       , 0.8099903, 2.8275902, ..., 0.       , 0.       ,
#        1.0816495], dtype=float32), array([0.00362244, 0.        , 0.82107866, ..., 0.        , 0.1243109 ,
#        0.26179948], dtype=float32), array([0.       , 2.0713048, 1.5240899, ..., 0.8756991, 0.       ,
#        0.       ], dtype=float32), array([0.70808923, 1.4959126 , 0.1135855 , ..., 0.0551529 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.20109892, 1.3414423 , ..., 1.3554119 , 0.        ,
#        0.3531357 ], dtype=float32), array([0.10686539, 0.00758583, 0.03288287, ..., 0.03171243, 0.23486549,
#        0.72598076], dtype=float32), array([0.01593953, 0.49550232, 0.        , ..., 0.9002042 , 0.05235731,
#        0.37297457], dtype=float32), array([0.        , 2.6707275 , 2.0274067 , ..., 2.0576153 , 0.        ,
#        0.01307551], dtype=float32), array([0.        , 0.2675177 , 2.5299478 , ..., 1.6727713 , 0.8179436 ,
#        0.25348455], dtype=float32), array([0.        , 1.5696023 , 2.562624  , ..., 0.15073927, 0.        ,
#        0.19320466], dtype=float32), array([0.        , 2.3765972 , 0.32163075, ..., 1.1391196 , 0.        ,
#        0.04087127], dtype=float32), array([0.        , 2.3530703 , 0.03456654, ..., 0.01698243, 0.01197637,
#        0.        ], dtype=float32), array([2.063005  , 1.1746686 , 1.3704019 , ..., 0.        , 0.14307866,
#        2.0443368 ], dtype=float32), array([0.7005327 , 3.0177252 , 1.8064246 , ..., 1.3275084 , 0.23101552,
#        0.09443747], dtype=float32), array([0.        , 0.6915152 , 1.2598271 , ..., 0.05622433, 0.        ,
#        0.4102812 ], dtype=float32), array([0.05915868, 0.7195991 , 1.9148333 , ..., 0.9042343 , 1.3971951 ,
#        0.04783411], dtype=float32), array([0.        , 1.9340347 , 2.6813865 , ..., 2.3703156 , 0.10117226,
#        0.        ], dtype=float32), array([0.21980709, 3.0162013 , 0.10046013, ..., 1.9187717 , 0.7674751 ,
#        0.6291263 ], dtype=float32), array([0.        , 3.3289175 , 0.        , ..., 0.        , 0.        ,
#        0.82257164], dtype=float32), array([0.01353668, 4.2082357 , 2.5081284 , ..., 0.31026733, 0.60893536,
#        0.38503042], dtype=float32), array([0.3120441, 0.0863374, 0.7124079, ..., 0.0277055, 0.1154585,
#        0.9984893], dtype=float32), array([0.00886734, 1.9997901 , 1.1077157 , ..., 0.3623231 , 0.        ,
#        0.31130487], dtype=float32), array([0.03365421, 0.4506783 , 0.69757813, ..., 0.7648628 , 0.00734623,
#        0.05473254], dtype=float32), array([0.        , 2.8440404 , 0.21361169, ..., 0.        , 0.2031677 ,
#        0.        ], dtype=float32), array([0.        , 0.40797737, 0.        , ..., 0.11162291, 0.34097502,
#        0.4618901 ], dtype=float32), array([ 2.12891   , 10.152516  ,  0.04827764, ...,  0.14740747,
#         0.        ,  0.19281815], dtype=float32), array([0.        , 0.1933506 , 0.01327796, ..., 0.        , 0.        ,
#        0.00922991], dtype=float32), array([0.        , 0.7353879 , 0.        , ..., 0.17558865, 0.34163505,
#        0.01507702], dtype=float32), array([0.07775606, 0.00553315, 2.548141  , ..., 0.12332444, 0.        ,
#        0.9510553 ], dtype=float32), array([0.        , 1.2489483 , 2.1394038 , ..., 0.        , 0.00755714,
#        0.        ], dtype=float32), array([0.01088719, 3.3439114 , 0.16579336, ..., 0.36038446, 0.05537096,
#        0.12472183], dtype=float32), array([0.04076585, 0.34280533, 0.        , ..., 0.10515481, 0.70498466,
#        0.04075221], dtype=float32), array([0.6718086 , 0.5182246 , 1.1873323 , ..., 0.86013293, 0.        ,
#        0.58848923], dtype=float32), array([0.        , 0.2311672 , 0.21158737, ..., 0.29830927, 0.00335075,
#        0.2697688 ], dtype=float32), array([0.03269802, 0.        , 0.        , ..., 0.26243377, 0.        ,
#        0.12534402], dtype=float32), array([0.25645143, 2.7138355 , 0.5531783 , ..., 0.3646437 , 0.018367  ,
#        1.1674803 ], dtype=float32), array([0.78046733, 0.7497469 , 0.06798065, ..., 0.6219065 , 0.        ,
#        1.290658  ], dtype=float32), array([0.31473765, 4.19676   , 0.        , ..., 0.03711137, 0.        ,
#        0.9691316 ], dtype=float32), array([0.14727996, 0.43791252, 1.0864716 , ..., 0.07101391, 0.        ,
#        0.        ], dtype=float32), array([1.5389423 , 1.3823828 , 4.968697  , ..., 0.01794323, 2.027429  ,
#        0.        ], dtype=float32), array([0.05030698, 0.4991435 , 0.08485654, ..., 0.86333144, 0.3795142 ,
#        0.6632594 ], dtype=float32), array([0.        , 0.64752644, 0.        , ..., 0.31329542, 0.0698268 ,
#        0.02302905], dtype=float32), array([0.        , 4.15434   , 0.1961275 , ..., 0.32595024, 0.3342483 ,
#        0.11338483], dtype=float32), array([1.0510527 , 1.0211446 , 1.2841861 , ..., 0.7910288 , 0.37856275,
#        0.5559284 ], dtype=float32), array([0.        , 0.43536788, 2.1608677 , ..., 0.        , 0.18482444,
#        0.        ], dtype=float32), array([0.27678776, 0.        , 1.3355712 , ..., 0.9735189 , 2.4408216 ,
#        3.162911  ], dtype=float32), array([0.27152234, 2.181076  , 2.1432483 , ..., 1.290158  , 1.1597911 ,
# ...
#        0.        ], dtype=float32), array([0.9369079, 3.606283 , 0.       , ..., 1.267564 , 2.2205844,
#        0.       ], dtype=float32), array([0.        , 0.9617601 , 0.2998646 , ..., 0.01839123, 0.        ,
#        0.        ], dtype=float32), array([0.        , 4.0266976 , 0.        , ..., 0.        , 1.0965767 ,
#        0.05405471], dtype=float32), array([0.04890668, 0.9247445 , 0.06112883, ..., 0.33030784, 0.04750422,
#        0.05428922], dtype=float32), array([0.        , 0.65534323, 0.13702857, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.2554442, 1.6179017, 0.       , ..., 0.       , 0.       ,
#        0.946558 ], dtype=float32), array([0.        , 8.037714  , 0.        , ..., 0.        , 0.02109868,
#        0.97019047], dtype=float32), array([0.        , 0.0184238 , 1.4371221 , ..., 0.02937143, 0.04048058,
#        0.26773813], dtype=float32), array([0.11260684, 1.807505  , 0.        , ..., 0.        , 0.        ,
#        1.2471902 ], dtype=float32), array([0.5335207 , 0.        , 1.4153574 , ..., 0.        , 0.02681025,
#        0.        ], dtype=float32), array([0.        , 0.        , 2.7658298 , ..., 0.        , 0.06039617,
#        0.5798721 ], dtype=float32), array([0.        , 1.3651197 , 0.00311754, ..., 0.03331704, 0.        ,
#        0.        ], dtype=float32), array([0.5535443 , 0.70084584, 2.3115625 , ..., 1.1279571 , 0.07963885,
#        0.23171273], dtype=float32), array([0.61500317, 0.6450702 , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.6244716 , 0.01379017, ..., 0.        , 0.35567686,
#        0.09655477], dtype=float32), array([0.80446386, 0.09461896, 0.4541499 , ..., 1.7488712 , 0.06547004,
#        0.51397943], dtype=float32), array([0.       , 0.       , 0.0740005, ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([1.1231408 , 2.3900423 , 2.5466578 , ..., 0.79967403, 0.        ,
#        0.        ], dtype=float32), array([0.5070715 , 3.1975865 , 0.        , ..., 0.        , 0.        ,
#        0.41823986], dtype=float32), array([0.041078  , 0.7088286 , 0.18232048, ..., 0.80980384, 0.        ,
#        0.        ], dtype=float32), array([0.02686005, 0.41054824, 1.1450498 , ..., 0.        , 0.06714761,
#        0.22698483], dtype=float32), array([0.01791234, 2.5691185 , 0.1553241 , ..., 1.6250889 , 0.08001252,
#        0.13205767], dtype=float32), array([0.05957682, 1.1103563 , 1.3551004 , ..., 0.7633083 , 0.00679227,
#        0.03837556], dtype=float32), array([0.7005327 , 3.0177252 , 1.8064246 , ..., 1.3275084 , 0.23101552,
#        0.09443747], dtype=float32), array([2.2264398e-03, 2.3324072e-02, 4.7894660e-01, ..., 3.4470081e+00,
#        2.1306343e+00, 0.0000000e+00], dtype=float32)]
# USER PROFILE:
# [[0.33222905 1.3296597  0.70232767 ... 0.43694648 0.3020407  0.32603103]]
# SIMILARITIES:
# (4287,)
# VECTORS:
# [array([0.        , 5.2143216 , 0.03044846, ..., 0.19556363, 0.        ,
#        0.88353574], dtype=float32), array([0.13193133, 1.6447706 , 0.5181644 , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.24609762, 1.6343794 , 0.        , ..., 0.        , 0.        ,
#        0.6032183 ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.3647148, 4.704932 ,
#        0.       ], dtype=float32), array([0.01243587, 2.0288258 , 1.0840952 , ..., 0.68477917, 0.        ,
#        0.6100768 ], dtype=float32), array([0.        , 0.9267291 , 0.07577386, ..., 0.15105787, 0.        ,
#        0.9676671 ], dtype=float32), array([0.21208467, 2.3917277 , 2.0804684 , ..., 0.5123825 , 0.        ,
#        0.56277937], dtype=float32), array([0.        , 0.        , 1.5282971 , ..., 0.0687809 , 0.        ,
#        0.77343833], dtype=float32), array([0.0000000e+00, 5.8909848e-02, 1.0748661e+00, ..., 4.4230931e-04,
#        3.2078415e-02, 1.1113925e+00], dtype=float32), array([0.       , 1.5451655, 0.       , ..., 0.       , 0.       ,
#        0.3754183], dtype=float32), array([0.       , 1.2452191, 1.4850101, ..., 1.1312001, 0.       ,
#        0.3087529], dtype=float32), array([0.08297257, 1.2789924 , 0.        , ..., 0.25609294, 0.01402568,
#        0.19163617], dtype=float32), array([0.6085434, 1.4595788, 0.2560392, ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.        , 2.0306754 , 0.12786266, ..., 2.0664556 , 0.24375053,
#        0.32215956], dtype=float32), array([0.       , 0.       , 2.622939 , ..., 0.5080696, 0.5351277,
#        3.4315782], dtype=float32), array([0.00576389, 0.        , 0.35603458, ..., 0.        , 0.        ,
#        0.13847466], dtype=float32), array([0.        , 0.06910913, 0.79936975, ..., 0.        , 0.        ,
#        0.02608882], dtype=float32), array([0.        , 2.916194  , 0.02053373, ..., 2.544323  , 2.6562762 ,
#        0.282668  ], dtype=float32), array([0.        , 1.8384616 , 0.        , ..., 0.02306659, 0.        ,
#        0.8145067 ], dtype=float32), array([0.        , 0.        , 1.1460581 , ..., 0.29984987, 0.24846916,
#        0.        ], dtype=float32), array([0.        , 2.25461   , 0.22729689, ..., 0.40411264, 0.        ,
#        0.06177269], dtype=float32), array([0.        , 0.10830353, 0.02064675, ..., 0.281519  , 0.        ,
#        0.05640334], dtype=float32), array([0.04933441, 0.4772697 , 0.3648431 , ..., 0.87517834, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.58109283, 0.        , ..., 0.14245412, 0.3079927 ,
#        0.        ], dtype=float32), array([0.14410691, 1.5012031 , 0.13841146, ..., 0.        , 0.14573725,
#        0.        ], dtype=float32), array([0.        , 0.97739714, 0.        , ..., 0.25202185, 0.        ,
#        0.5068515 ], dtype=float32), array([0.        , 2.052932  , 0.00889368, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.23796105, 0.        , 0.5165775 , ..., 0.5024184 , 0.19277993,
#        0.08553353], dtype=float32), array([1.2722473 , 0.        , 7.040516  , ..., 0.04709309, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.3330511 , 0.08915955, ..., 0.        , 0.01587195,
#        0.        ], dtype=float32), array([1.8407555 , 0.        , 0.17169558, ..., 0.11428244, 0.        ,
#        0.08921488], dtype=float32), array([0.        , 0.16422154, 0.37020385, ..., 0.        , 0.        ,
#        0.48625717], dtype=float32), array([0.00754802, 0.        , 0.1062231 , ..., 0.11249807, 0.        ,
#        0.        ], dtype=float32), array([0.01666323, 0.        , 0.50310814, ..., 0.        , 0.        ,
#        0.78287023], dtype=float32), array([0.        , 0.9425768 , 0.02032449, ..., 1.9046918 , 0.5083108 ,
#        0.        ], dtype=float32), array([0.       , 0.7948446, 0.       , ..., 0.       , 1.187324 ,
#        1.1368427], dtype=float32), array([1.4711951 , 1.8975983 , 0.        , ..., 0.23823553, 0.20517589,
#        0.12276614], dtype=float32), array([0.4545265 , 0.25139728, 0.02663058, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.78354806, 2.028964  , 0.17119738, ..., 0.34389213, 0.        ,
#        0.2317304 ], dtype=float32), array([3.3137693 , 0.22605027, 1.7264682 , ..., 0.3275826 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.26243752, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([1.4723352 , 0.9411055 , 1.0127913 , ..., 0.42301202, 1.6168643 ,
#        0.03862717], dtype=float32), array([0.       , 1.9755595, 4.4957995, ..., 0.9934212, 2.1018991,
#        0.9310249], dtype=float32), array([0.        , 4.4647927 , 0.        , ..., 0.13496938, 0.11127049,
#        0.0122947 ], dtype=float32), array([0.        , 0.32854724, 0.2001894 , ..., 0.26274717, 0.        ,
#        0.08688491], dtype=float32), array([0.        , 0.12498425, 0.33748847, ..., 0.7536406 , 0.        ,
#        0.        ], dtype=float32), array([0.09150675, 4.641165  , 0.        , ..., 0.        , 0.55801755,
#        1.056209  ], dtype=float32), array([0.06871787, 1.2718511 , 4.7959557 , ..., 0.6850512 , 0.        ,
#        1.337094  ], dtype=float32), array([0.8803941 , 1.7275782 , 0.9322471 , ..., 2.1098647 , 0.97081745,
#        0.        ], dtype=float32), array([0.05035001, 0.84381855, 0.6622175 , ..., 1.411663  , 0.        ,
#        0.6023087 ], dtype=float32), array([0.7707033 , 2.2057934 , 0.0551233 , ..., 0.95666945, 0.        ,
#        0.15509948], dtype=float32), array([0.5762568 , 5.2769184 , 0.77892464, ..., 0.07988828, 0.05163283,
#        0.6746204 ], dtype=float32), array([0.       , 0.       , 4.246139 , ..., 0.6995859, 0.3473543,
#        1.2196747], dtype=float32), array([0.        , 2.1504688 , 0.        , ..., 0.18566883, 0.22849503,
#        0.03601294], dtype=float32), array([0.        , 0.        , 0.22698629, ..., 0.15216035, 0.        ,
#        0.14791787], dtype=float32), array([0.41596812, 0.38157812, 1.118973  , ..., 0.        , 0.75082   ,
#        0.07052692], dtype=float32), array([0.08354516, 0.2540177 , 0.        , ..., 0.13462944, 0.        ,
#        0.02863983], dtype=float32), array([0.6849727, 1.1750851, 1.4684899, ..., 1.935763 , 0.3515906,
#        0.4439873], dtype=float32), array([0.        , 1.9049052 , 0.01873251, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.24354182, 0.        , ..., 1.7948782 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.78599477, 1.2899737 , ..., 0.        , 0.        ,
#        0.15414853], dtype=float32), array([0.        , 3.5183482 , 0.7990112 , ..., 0.2562728 , 1.1140186 ,
#        0.18888602], dtype=float32), array([0.04746864, 0.99794555, 0.3125961 , ..., 0.4573928 , 0.        ,
#        1.1995188 ], dtype=float32), array([0.       , 2.9353874, 0.       , ..., 0.423741 , 0.       ,
#        0.       ], dtype=float32), array([0.30975264, 2.3271537 , 0.28650022, ..., 0.04290487, 0.        ,
#        0.        ], dtype=float32), array([0.2149861 , 2.9157844 , 0.9507679 , ..., 0.03083177, 0.        ,
#        0.        ], dtype=float32), array([0.        , 1.0180924 , 0.13893896, ..., 0.06608152, 0.        ,
#        2.5403707 ], dtype=float32), array([0.        , 0.42708433, 0.4346453 , ..., 0.2051982 , 0.05703465,
#        0.07872121], dtype=float32), array([0.        , 1.8814958 , 0.41669038, ..., 0.32835916, 0.14209233,
#        0.59251773], dtype=float32), array([0.        , 0.        , 0.01435222, ..., 0.        , 0.11273571,
#        0.        ], dtype=float32), array([0.        , 0.29688555, 0.        , ..., 0.16582078, 0.5059469 ,
#        0.        ], dtype=float32), array([1.3651023 , 2.361254  , 0.16370577, ..., 0.43236572, 0.93363416,
#        0.9856092 ], dtype=float32), array([2.8757221e-04, 0.0000000e+00, 9.8159486e-01, ..., 6.0124254e-01,
#        0.0000000e+00, 0.0000000e+00], dtype=float32), array([1.9671717 , 0.07624739, 0.        , ..., 0.54698753, 3.9525616 ,
#        0.89918226], dtype=float32), array([0.        , 1.169925  , 0.14430237, ..., 0.        , 0.        ,
#        0.69911397], dtype=float32), array([0.        , 0.7949415 , 1.4906875 , ..., 0.        , 0.        ,
#        0.11412997], dtype=float32), array([0.        , 0.02639481, 0.46779227, ..., 0.42412788, 0.        ,
#        0.12239255], dtype=float32), array([0.3621274 , 0.39940444, 0.08156059, ..., 0.03270989, 0.42548835,
#        0.        ], dtype=float32), array([0.        , 0.74316525, 0.01903758, ..., 0.34289992, 1.4019186 ,
#        0.19204278], dtype=float32), array([0.        , 0.41461155, 0.0215442 , ..., 0.1358029 , 0.        ,
#        0.07728898], dtype=float32), array([0.10522304, 0.7844999 , 1.7671514 , ..., 1.4984404 , 0.        ,
#        0.6976942 ], dtype=float32), array([0.00604439, 0.        , 0.7603892 , ..., 0.21003708, 0.12546302,
#        0.        ], dtype=float32), array([0.10397809, 4.1295033 , 0.02844572, ..., 0.10896641, 0.        ,
#        0.32003403], dtype=float32), array([0.        , 0.9438245 , 0.        , ..., 1.0772976 , 0.14619026,
#        0.240332  ], dtype=float32), array([0.       , 0.1683076, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.14781034, 1.0466843 , 0.        , ..., 0.06991649, 0.02804396,
#        0.        ], dtype=float32), array([0.09263193, 0.70402014, 0.        , ..., 0.19787464, 0.        ,
#        0.03816366], dtype=float32), array([0.        , 0.        , 0.07163586, ..., 0.04713052, 0.        ,
#        0.03126158], dtype=float32), array([0.40518504, 0.        , 0.06687999, ..., 0.        , 0.        ,
#        0.55179477], dtype=float32), array([0.        , 2.7038462 , 1.9389164 , ..., 0.00658885, 0.        ,
#        0.01056255], dtype=float32), array([0.        , 1.3122206 , 0.65327287, ..., 0.50757575, 0.48143464,
#        0.3682558 ], dtype=float32), array([0.593349  , 0.455113  , 0.19624338, ..., 0.00955397, 0.        ,
#        0.        ], dtype=float32), array([0.        , 1.6330453 , 0.        , ..., 0.8861809 , 0.21117795,
#        0.34585685], dtype=float32), array([0.01163423, 0.5308628 , 0.        , ..., 0.28773218, 1.2968909 ,
#        0.23297092], dtype=float32), array([1.6339191 , 0.66023785, 1.8427224 , ..., 1.9311941 , 0.        ,
#        0.95206267], dtype=float32), array([0.6972881 , 0.5182284 , 0.05914927, ..., 0.        , 0.07662411,
#        0.        ], dtype=float32), array([0.13651758, 0.1509076 , 0.58629143, ..., 0.64615726, 0.        ,
#        0.09952656], dtype=float32), array([2.2700014 , 3.4316769 , 0.        , ..., 0.81540835, 1.2407255 ,
#        0.5041394 ], dtype=float32), array([0.21025369, 0.00749521, 0.0346037 , ..., 0.2199448 , 2.2310653 ,
#        0.2559847 ], dtype=float32), array([1.0104878 , 1.5450429 , 0.        , ..., 0.        , 0.08734526,
#        0.3608065 ], dtype=float32), array([0.        , 1.9886563 , 0.19099008, ..., 0.        , 0.        ,
#        0.06970481], dtype=float32), array([0.        , 0.14153433, 0.34106717, ..., 0.22813778, 0.03445793,
#        0.        ], dtype=float32), array([0.1326971 , 2.0607128 , 0.        , ..., 0.38425988, 0.        ,
#        0.22756188], dtype=float32), array([0.17334335, 0.27863458, 1.4990704 , ..., 0.18322179, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.57160836, 0.        , ..., 1.0483267 , 0.13272737,
#        0.        ], dtype=float32), array([0.19692552, 0.83666027, 0.22555436, ..., 0.01703721, 0.        ,
#        0.02152655], dtype=float32), array([0.25645143, 2.7138355 , 0.5531783 , ..., 0.3646437 , 0.018367  ,
#        1.1674803 ], dtype=float32), array([1.4021165 , 0.20115733, 0.        , ..., 0.        , 0.17612198,
#        0.60850763], dtype=float32), array([0.        , 1.2765296 , 0.05852498, ..., 0.40075797, 0.15504523,
#        0.        ], dtype=float32), array([0.11414043, 0.74006766, 0.        , ..., 0.        , 0.        ,
#        0.1289573 ], dtype=float32), array([0.        , 0.        , 0.44059572, ..., 0.00377517, 0.        ,
#        0.        ], dtype=float32), array([0.        , 1.5298486 , 0.10638475, ..., 1.7315642 , 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.        , 0.33266634, ..., 0.        , 0.        ,
#        0.19208968], dtype=float32), array([0.        , 0.        , 0.8156241 , ..., 0.        , 0.        ,
#        0.04736124], dtype=float32), array([0.        , 4.592539  , 0.        , ..., 0.        , 0.        ,
#        0.91361284], dtype=float32), array([0.14301804, 1.8926733 , 0.07189097, ..., 0.3255261 , 0.        ,
#        0.        ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#        0.8974384], dtype=float32), array([2.2769055 , 0.22411416, 0.36665124, ..., 0.05823312, 0.        ,
#        0.        ], dtype=float32), array([0.        , 0.23133749, 0.57602465, ..., 0.        , 0.13282347,
#        0.14338651], dtype=float32), array([0.        , 0.97262836, 0.39388072, ..., 2.7085958 , 0.5178094 ,
#        0.44155324], dtype=float32)]
# USER PROFILE:
# [[0.26977548 1.1237872  0.5609347  ... 0.39610988 0.28186968 0.3293092 ]]
# SIMILARITIES:
# (4287,)
# Se evaluaron 100 usuarios en total.
#
# PRECISION@10: 0.0050
# RECALL@10: 0.0050
# NDCG@10: 0.0062
# MAP@10: 0.0021
